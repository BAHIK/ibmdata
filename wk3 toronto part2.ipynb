# %%
# import libraries
# %matplotlib inline
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
# download wiki page
page = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
page.status_code
# Out:
# 200

# %%
# use BeautifulSoup to parse the page
soup = BeautifulSoup(page.content, 'html.parser')
#soup

# %%
# exact table as table
soup.find('table', {"class":"wikitable sortable"})
table = soup.find('table', {"class":"wikitable sortable"})
#table

# %%
# Print the first 10 rows
rows1 = table.find_all('td')
rows1[:10]
# Out:
# [<td>M1A</td>, <td>Not assigned</td>, <td>Not assigned
#  </td>, <td>M2A</td>, <td>Not assigned</td>, <td>Not assigned
#  </td>, <td>M3A</td>, <td><a href="/wiki/North_York" title="North York">North York</a></td>, <td><a href="/wiki/Parkwoods" title="Parkwoods">Parkwoods</a>
#  </td>, <td>M4A</td>]

# %%
# extract columns
rows2 = str(rows1)
clean = BeautifulSoup(rows2, "lxml").get_text()
#print(clean)
#clean[2]

# %%
# split strings by ','
a=clean.split(', ')
a[:12]
# Out:
# ['[M1A',
#  'Not assigned',
#  'Not assigned\n',
#  'M2A',
#  'Not assigned',
#  'Not assigned\n',
#  'M3A',
#  'North York',
#  'Parkwoods\n',
#  'M4A',
#  'North York',
#  'Victoria Village\n']

# %%
# save values in a list
b=[]
for i in a:
        b.append(i.rstrip())
b[:12]
# Out:
# ['[M1A',
#  'Not assigned',
#  'Not assigned',
#  'M2A',
#  'Not assigned',
#  'Not assigned',
#  'M3A',
#  'North York',
#  'Parkwoods',
#  'M4A',
#  'North York',
#  'Victoria Village']

# %%
# create lists
postcodelist=[]
boroughlist=[]
neighbourhoodlist=[]

# %%
# save values in separate columns
c=len(b)
print(c)
i=1
j=0
while i <=c-2:
    if (b[i]!='Not assigned'):
        if (b[i+1]!='Not assigned'):
            postcodelist.append(b[i-1])
            boroughlist.append(b[i])
            neighbourhoodlist.append(b[i+1])
            i=i+3
            j=j+1 
        else:
            postcodelist.append(b[i-1])
            boroughlist.append(b[i])
            neighbourhoodlist.append(b[i])
            i=i+3
            j=j+1
    else:
        i=i+3
        j=j+1        

#print(i)
#print(j)
#print(len(postcodelist))
#print(len(boroughlist))
#print(len(neighbourhoodlist))
# Out:
# 864

# %%
# check columns
print(postcodelist[-5:])
print(boroughlist[-5:])
print(neighbourhoodlist[-5:])
# Out:
# ['M8Z', 'M8Z', 'M8Z', 'M8Z', 'M8Z']
# ['Etobicoke', 'Etobicoke', 'Etobicoke', 'Etobicoke', 'Etobicoke']
# ['Kingsway Park South West', 'Mimico NW', 'The Queensway West', 'Royal York South West', 'South of Bloor']

# %%
# create an empty dataframe
colname=['PostalCode','Borough','Neighbourhood']
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# create dataframe
df1['PostalCode']=postcodelist
df1['Borough']=boroughlist
df1['Neighbourhood']=neighbourhoodlist
#df1.head()
df1
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M5A  Downtown Toronto
# 4          M6A        North York
# 5          M6A        North York
# 6          M7A      Queen's Park
# 7          M9A         Etobicoke
# 8          M1B       Scarborough
# 9          M1B       Scarborough
# 10         M3B        North York
# 11         M4B         East York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M5B  Downtown Toronto
# 15         M6B        North York
# 16         M9B         Etobicoke
# 17         M9B         Etobicoke
# 18         M9B         Etobicoke
# 19         M9B         Etobicoke
# 20         M9B         Etobicoke
# 21         M1C       Scarborough
# 22         M1C       Scarborough
# 23         M1C       Scarborough
# 24         M3C        North York
# 25         M3C        North York
# 26         M4C         East York
# ...

# %%
# groupby columns
df2=df1.groupby(['PostalCode','Borough'])['Neighbourhood'].apply(','.join).reset_index()
#df2.head()
df2
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# ...

# %%
df2.shape
# Out:
# (103, 3)

# %%
import csv

# %%
df3=pd.read_csv('https://cocl.us/Geospatial_data')
df3.rename(columns={'Postal Code': 'PostalCode'}, inplace=True)
df3['Latitude']=df3['Latitude'].astype(str)
df3['Longitude']=df3['Longitude'].astype(str)
df3.head()
# Out:
#   PostalCode    Latitude    Longitude
# 0        M1B  43.8066863  -79.1943534
# 1        M1C  43.7845351  -79.1604971
# 2        M1E  43.7635726  -79.1887115
# 3        M1G  43.7709921  -79.2169174
# 4        M1H   43.773136  -79.2394761

# %%
df4=[]
df4=df2.merge(df3)
#df4.head()
df4
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# ...
