# %%
# %matplotlib inline

import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     altair-2.2.2               |           py35_1         462 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          2.2.2-py35_1      conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.1.23-0                   --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2018.8.24-py35_1              --> 2018.8.24-py35_1001  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.0.2s-h7b6447c_0             --> 1.0.2r-h14c3975_0    conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# openssl-1.0.2r       | 3.1 MB    | ##################################### | 100%
# altair-2.2.2         | 462 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
# import population and geographic coordinate datasets, define Foursquare Credentials and Version

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# import population data
calpop = pd.read_csv(body)
#calpop.rename(columns={'City':'name'}, inplace=True)
calpop.head()
# Out:
#            County          City Incorportation_date  pop_april_1980  \
# 0  San Bernardino      Adelanto                1970          2164.0
# 1     Los Angeles  Agoura Hills                1982             NaN
# 2         Alameda       Alameda                1854         63852.0
# 3         Alameda        Albany                1908         15130.0
# 4     Los Angeles      Alhambra                1903         64767.0
#
#    pop_april_1990  pop_april_2000  pop_april_2010
# 0            8517           18130           31765
# 1           20390           20537           20330
# 2           76459           72259           73812
# 3           16327           16444           18539
# 4           82106           85804           83089

# %%
# The code was removed by Watson Studio for sharing.

# %%
# import geo coordinates
calloc = pd.read_csv(body)
calloc.rename(columns={'Name':'City'}, inplace=True)
calloc.head()
# Out:
#            City   Latitude   Longitude
# 0      Adelanto  34.582769 -117.409214
# 1  Agoura Hills  34.153339 -118.761675
# 2       Alameda  37.765206 -122.241636
# 3        Albany  37.886869 -122.297747
# 4      Alhambra  34.095286 -118.127014

# %%
# merge popoulation and coordinates by city
df1=calpop.merge(calloc)
df1.head()
# Out:
#            County          City Incorportation_date  pop_april_1980  \
# 0  San Bernardino      Adelanto                1970          2164.0
# 1     Los Angeles  Agoura Hills                1982             NaN
# 2         Alameda       Alameda                1854         63852.0
# 3         Alameda        Albany                1908         15130.0
# 4     Los Angeles      Alhambra                1903         64767.0
#
#    pop_april_1990  pop_april_2000  pop_april_2010   Latitude   Longitude
# 0            8517           18130           31765  34.582769 -117.409214
# 1           20390           20537           20330  34.153339 -118.761675
# 2           76459           72259           73812  37.765206 -122.241636
# 3           16327           16444           18539  37.886869 -122.297747
# 4           82106           85804           83089  34.095286 -118.127014

# %%
df1.groupby('County')['City'].count()
# Out:
# County
# Alameda            14
# Amador              5
# Butte               4
# Calaveras           1
# Colusa              2
# Contra Costa       16
# Del Norte           1
# El Dorado           2
# Fresno             15
# Glenn               2
# Humboldt            7
# Imperial            7
# Inyo                1
# Kern               11
# Kings               4
# Lake                1
# Lassen              1
# Los Angeles        86
# Madera              2
# Marin               6
# Mendocino           4
# Merced              6
# Modoc               1
# Monterey           11
# Napa                3
# Nevada              2
# Orange             29
# Placer              5
# Plumas              1
# Riverside          21
# Sacramento          4
# San Benito          2
# San Bernardino     21
# San Diego          18
# San Francisco       1
# San Joaquin         7
# San Luis Obispo     7
# San Mateo          15
# Santa Barbara       6
# Santa Clara        13
# Santa Cruz          4
# Shasta              2
# Sierra              1
# Siskiyou            9
# Solano              6
# Sonoma              8
# Stanislaus          9
# Sutter              2
# Tehama              3
# Tulare              8
# Tuolumne            1
# Ventura            10
# Yolo                4
# Yuba                2
# Name: City, dtype: int64

# %%
# filter San Diego County data
df2=df1[df1['County']=='San Diego'].reset_index(drop=True)
df2.head()
#df2.shape
# Out:
#       County         City Incorportation_date  pop_april_1980  pop_april_1990  \
# 0  San Diego     Carlsbad                1952         35490.0           63126
# 1  San Diego  Chula Vista                1911         35490.0           63126
# 2  San Diego     Coronado                1890         18790.0           26540
# 3  San Diego      Del Mar                1959          5017.0            4860
# 4  San Diego     El Cajon                1912         73892.0           88693
#
#    pop_april_2000  pop_april_2010   Latitude   Longitude
# 0           78247          105328  33.158092 -117.350594
# 1          173556          243916  32.640053 -117.084197
# 2           24100           18912  32.685886 -117.183089
# 3            4389            4161  32.959489 -117.265314
# 4           94869           99478  32.794772 -116.962528

# %%
# delete unwanted columns
df3=df2.drop(['County','Incorportation_date','pop_april_1980','pop_april_1990','pop_april_2000'],axis=1)
df3.rename(columns={'pop_april_2010':'pop'}, inplace=True)
df3
# Out:
#               City      pop   Latitude   Longitude
# 0         Carlsbad   105328  33.158092 -117.350594
# 1      Chula Vista   243916  32.640053 -117.084197
# 2         Coronado    18912  32.685886 -117.183089
# 3          Del Mar     4161  32.959489 -117.265314
# 4         El Cajon    99478  32.794772 -116.962528
# 5        Encinitas    59518  33.036986 -117.291983
# 6        Escondido   143911  33.119208 -117.086422
# 7   Imperial Beach    26324  32.583944 -117.113086
# 8          La Mesa    57065  32.767828 -117.023083
# 9      Lemon Grove    25320  32.742553 -117.031417
# 10   National City    58582  32.678108 -117.099197
# 11       Oceanside   167086  33.195869 -117.379483
# 12           Poway    47811  32.962822 -117.035864
# 13       San Diego  1307402  32.715328 -117.157256
# 14      San Marcos    83781  33.143372 -117.166144
# 15          Santee    53413  32.838383 -116.973917
# 16    Solana Beach    12867  32.991156 -117.271147
# 17           Vista    93834  33.200036 -117.242536

# %%
# create map of San Diego using latitude and longitude values
latitude = 32.7157
longitude = -117.1611
#print('The geograpical coordinate of San Diego are {}, {}.'.format(latitude, longitude))

map1 = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, city, pop in zip(df3['Latitude'], df3['Longitude'], df3['City'], df3['pop']):
    label = '{}, {}'.format(city, pop)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map1)  
    
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define function for getting venues from Foursquare API

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    LIMIT=500
    venues_list=[]
        
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['City', 
                  'Latitude', 
                  'Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']

    return(nearby_venues)

# %%
# getting venues of San Diego from Foursquare API
sd_venues = getNearbyVenues(names=df2['City'],
                                   latitudes=df2['Latitude'],
                                   longitudes=df2['Longitude']
                                  )
# Out:
# Carlsbad
# Chula Vista
# Coronado
# Del Mar
# El Cajon
# Encinitas
# Escondido
# Imperial Beach
# La Mesa
# Lemon Grove
# National City
# Oceanside
# Poway
# San Diego
# San Marcos
# Santee
# Solana Beach
# Vista

# %%
# check venue result
print(sd_venues.shape)
sd_venues.head()
sd_venues.tail()
# Out:
# (699, 7)
#       City   Latitude   Longitude                   Venue  Venue Latitude  \
# 694  Vista  33.200036 -117.242536     Vista Village Plaza       33.200770
# 695  Vista  33.200036 -117.242536    Vista Transit Center       33.202995
# 696  Vista  33.200036 -117.242536          Crunch Fitness       33.197572
# 697  Vista  33.200036 -117.242536          Rodeo's Market       33.200669
# 698  Vista  33.200036 -117.242536  Rusty Nail Renovations       33.195812
#
#      Venue Longitude        Venue Category
# 694      -117.245609         Shopping Mall
# 695      -117.244811    Light Rail Station
# 696      -117.245898  Gym / Fitness Center
# 697      -117.246968         Grocery Store
# 698      -117.240913         Moving Target

# %%
# filter the grocery stores from all the cities in San Diego
df4=pd.DataFrame()
df4=sd_venues[sd_venues['Venue Category']=='Grocery Store']
df4
# Out:
#                City   Latitude   Longitude                           Venue  \
# 257       Escondido  33.119208 -117.086422            Smart & Final Extra!
# 280  Imperial Beach  32.583944 -117.113086                  Grocery Outlet
# 299         La Mesa  32.767828 -117.023083                            VONS
# 341     Lemon Grove  32.742553 -117.031417          Sprouts Farmers Market
# 401   National City  32.678108 -117.099197  Chan Dong Oriental Supermarket
# 402   National City  32.678108 -117.099197      Mothers nutritional center
# 567       San Diego  32.715328 -117.157256                  Grocery Outlet
# 586      San Marcos  33.143372 -117.166144                  San Marcos Gym
# 663           Vista  33.200036 -117.242536                   Frazier Farms
# 697           Vista  33.200036 -117.242536                  Rodeo's Market
#
#      Venue Latitude  Venue Longitude Venue Category
# 257       33.122506      -117.087514  Grocery Store
# 280       32.583659      -117.114633  Grocery Store
# 299       32.765336      -117.024285  Grocery Store
# 341       32.740505      -117.030014  Grocery Store
# 401       32.677389      -117.100612  Grocery Store
# 402       32.676662      -117.098464  Grocery Store
# 567       32.711764      -117.155108  Grocery Store
# 586       33.142503      -117.166866  Grocery Store
# 663       33.197798      -117.246055  Grocery Store
# 697       33.200669      -117.246968  Grocery Store

# %%
# count the grocery stores by cities
df5=df4.groupby('City')['Venue Category'].count()
df5=pd.DataFrame(df5).reset_index()
df5.rename(columns={'Venue Category':'Grocery Store'}, inplace=True)
df5
# Out:
#              City  Grocery Store
# 0       Escondido              1
# 1  Imperial Beach              1
# 2         La Mesa              1
# 3     Lemon Grove              1
# 4   National City              2
# 5       San Diego              1
# 6      San Marcos              1
# 7           Vista              2

# %%
# merge city basic info and numbers of grocery stores in each city
df6=pd.merge(df3, df5, how='outer')
df6.replace(np.nan,'0', inplace=True)
df6
# Out:
#               City      pop   Latitude   Longitude Grocery Store
# 0         Carlsbad   105328  33.158092 -117.350594             0
# 1      Chula Vista   243916  32.640053 -117.084197             0
# 2         Coronado    18912  32.685886 -117.183089             0
# 3          Del Mar     4161  32.959489 -117.265314             0
# 4         El Cajon    99478  32.794772 -116.962528             0
# 5        Encinitas    59518  33.036986 -117.291983             0
# 6        Escondido   143911  33.119208 -117.086422             1
# 7   Imperial Beach    26324  32.583944 -117.113086             1
# 8          La Mesa    57065  32.767828 -117.023083             1
# 9      Lemon Grove    25320  32.742553 -117.031417             1
# 10   National City    58582  32.678108 -117.099197             2
# 11       Oceanside   167086  33.195869 -117.379483             0
# 12           Poway    47811  32.962822 -117.035864             0
# 13       San Diego  1307402  32.715328 -117.157256             1
# 14      San Marcos    83781  33.143372 -117.166144             1
# 15          Santee    53413  32.838383 -116.973917             0
# 16    Solana Beach    12867  32.991156 -117.271147             0
# 17           Vista    93834  33.200036 -117.242536             2

# %%
# new store share: how many people share a grocery store if a new store opens in each city
# (number of grocery stores + 1) divided by population of each city
df6['pop']=df6['pop'].astype(int)
df6['Grocery Store']=df6['Grocery Store'].astype(int)
df6['New Store Share']= df6['pop']/(df6['Grocery Store']+1)
df6['New Store Share']=df6['New Store Share'].astype(int)
df6
# Out:
#               City      pop   Latitude   Longitude  Grocery Store  \
# 0         Carlsbad   105328  33.158092 -117.350594              0
# 1      Chula Vista   243916  32.640053 -117.084197              0
# 2         Coronado    18912  32.685886 -117.183089              0
# 3          Del Mar     4161  32.959489 -117.265314              0
# 4         El Cajon    99478  32.794772 -116.962528              0
# 5        Encinitas    59518  33.036986 -117.291983              0
# 6        Escondido   143911  33.119208 -117.086422              1
# 7   Imperial Beach    26324  32.583944 -117.113086              1
# 8          La Mesa    57065  32.767828 -117.023083              1
# 9      Lemon Grove    25320  32.742553 -117.031417              1
# 10   National City    58582  32.678108 -117.099197              2
# 11       Oceanside   167086  33.195869 -117.379483              0
# 12           Poway    47811  32.962822 -117.035864              0
# 13       San Diego  1307402  32.715328 -117.157256              1
# 14      San Marcos    83781  33.143372 -117.166144              1
# 15          Santee    53413  32.838383 -116.973917              0
# 16    Solana Beach    12867  32.991156 -117.271147              0
# 17           Vista    93834  33.200036 -117.242536              2
#
#     New Store Share
# 0            105328
# 1            243916
# 2             18912
# 3              4161
# 4             99478
# 5             59518
# 6             71955
# 7             13162
# 8             28532
# 9             12660
# 10            19527
# 11           167086
# 12            47811
# 13           653701
# 14            41890
# 15            53413
# 16            12867
# 17            31278

# %%
# sort data by population and number of grocery stores
df7=df6.sort_values(by=['New Store Share'], ascending=False)
df7 = df7.reset_index(drop=True)
df7
# Out:
#               City      pop   Latitude   Longitude  Grocery Store  \
# 0        San Diego  1307402  32.715328 -117.157256              1
# 1      Chula Vista   243916  32.640053 -117.084197              0
# 2        Oceanside   167086  33.195869 -117.379483              0
# 3         Carlsbad   105328  33.158092 -117.350594              0
# 4         El Cajon    99478  32.794772 -116.962528              0
# 5        Escondido   143911  33.119208 -117.086422              1
# 6        Encinitas    59518  33.036986 -117.291983              0
# 7           Santee    53413  32.838383 -116.973917              0
# 8            Poway    47811  32.962822 -117.035864              0
# 9       San Marcos    83781  33.143372 -117.166144              1
# 10           Vista    93834  33.200036 -117.242536              2
# 11         La Mesa    57065  32.767828 -117.023083              1
# 12   National City    58582  32.678108 -117.099197              2
# 13        Coronado    18912  32.685886 -117.183089              0
# 14  Imperial Beach    26324  32.583944 -117.113086              1
# 15    Solana Beach    12867  32.991156 -117.271147              0
# 16     Lemon Grove    25320  32.742553 -117.031417              1
# 17         Del Mar     4161  32.959489 -117.265314              0
#
#     New Store Share
# 0            653701
# 1            243916
# 2            167086
# 3            105328
# 4             99478
# 5             71955
# 6             59518
# 7             53413
# 8             47811
# 9             41890
# 10            31278
# 11            28532
# 12            19527
# 13            18912
# 14            13162
# 15            12867
# 16            12660
# 17             4161

# %%
# the city of most people share one grocery store
print(df7.iloc[0,0], 'is the new grocery store location.')
# Out:
# San Diego is the new grocery store location.

# %%
# filter all the venues in the city of 'San Diego'
df8=pd.DataFrame()
df8=sd_venues[sd_venues['City']=='San Diego']
print(df8.shape)
df8.head()
# Out:
# (100, 7)
#           City   Latitude   Longitude                          Venue  \
# 473  San Diego  32.715328 -117.157256            Best Damn Beer Shop
# 474  San Diego  32.715328 -117.157256              Art Hookah Lounge
# 475  San Diego  32.715328 -117.157256             Chef Miguel's Deli
# 476  San Diego  32.715328 -117.157256  Dog Haus Biergarten San Diego
# 477  San Diego  32.715328 -117.157256       Pokez Mexican Restaurant
#
#      Venue Latitude  Venue Longitude      Venue Category
# 473       32.716203      -117.158550          Beer Store
# 474       32.714935      -117.159274              Lounge
# 475       32.716500      -117.158690      Sandwich Place
# 476       32.715529      -117.156307       Hot Dog Joint
# 477       32.714574      -117.155761  Mexican Restaurant

# %%
# unique venue category
# a=df8['Venue Category'].unique()
# a
#a.count()

# %%
# filter all the restaurant
df9=df8[df8['Venue Category'].str.contains('Restaurant')]
print(df9.shape)
df9.head()
# Out:
# (34, 7)
#           City   Latitude   Longitude                      Venue  \
# 477  San Diego  32.715328 -117.157256   Pokez Mexican Restaurant
# 480  San Diego  32.715328 -117.157256  Tajima Ramen East Village
# 486  San Diego  32.715328 -117.157256               The Crab Hut
# 490  San Diego  32.715328 -117.157256            The Melting Pot
# 491  San Diego  32.715328 -117.157256           Empanada Kitchen
#
#      Venue Latitude  Venue Longitude       Venue Category
# 477       32.714574      -117.155761   Mexican Restaurant
# 480       32.714553      -117.156398     Ramen Restaurant
# 486       32.715802      -117.159871   Seafood Restaurant
# 490       32.714844      -117.159930    Fondue Restaurant
# 491       32.716635      -117.157114  Empanada Restaurant

# %%
# map all the restaurant in the city of San Diego using latitude and longitude values
latitude = 32.71528
longitude = -117.157256
#print('The geograpical coordinate of San Diego are {}, {}.'.format(latitude, longitude))

map2 = folium.Map(location=[latitude, longitude], zoom_start=15)

# add markers to map
for lat, lng, venue, cat in zip(df9['Venue Latitude'], df9['Venue Longitude'], df9['Venue'], df9['Venue Category']):
    label = '{}, {}'.format(venue, cat)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map2)  
    
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# DBSCAN clustering based on their location i.e. Lat & Lon
from sklearn.cluster import DBSCAN
import sklearn.utils
from sklearn.preprocessing import StandardScaler

coords = df9.as_matrix(columns=['Venue Latitude','Venue Longitude'])
sklearn.utils.check_random_state(1000)
Clus_dataSet = df9[['Venue Latitude','Venue Longitude']]
Clus_dataSet = np.nan_to_num(Clus_dataSet)
Clus_dataSet = StandardScaler().fit_transform(Clus_dataSet)

# Compute DBSCAN
db = DBSCAN(eps=0.00003, min_samples=1, algorithm='ball_tree', metric='haversine').fit(np.radians(coords))
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
df9["Clus_Db"]=labels

realClusterNum=len(set(labels)) - (1 if -1 in labels else 0)
clusterNum = len(set(labels)) 

# A sample of clusters
df10=df9[["Venue","Venue Latitude","Venue Longitude","Clus_Db"]]
df10
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                      Venue  Venue Latitude  Venue Longitude  \
# 477               Pokez Mexican Restaurant       32.714574      -117.155761
# 480              Tajima Ramen East Village       32.714553      -117.156398
# 486                           The Crab Hut       32.715802      -117.159871
# 490                        The Melting Pot       32.714844      -117.159930
# 491                       Empanada Kitchen       32.716635      -117.157114
# 492                             Brian's 24       32.714084      -117.159313
# 494                 Time Out Sports Tavern       32.715840      -117.158586
# 498                   Osetra the Fishhouse       32.714777      -117.160314
# 500                Trailer Park After Dark       32.714195      -117.160076
# 502                          Buca di Beppo       32.712895      -117.159095
# 507                            Rei Do Gado       32.715202      -117.160940
# 510                        Tocaya Organica       32.713324      -117.160084
# 512                            Grant Grill       32.716125      -117.161084
# 513                               Curadero       32.716193      -117.159832
# 515                                   Biga       32.715370      -117.159420
# 516              Döner Mediterranean Grill       32.713984      -117.160119
# 523                             Pho Xpress       32.717299      -117.159161
# 524            Albert's Fresh Mexican Food       32.716751      -117.153972
# 529                             Operacaffe       32.714041      -117.160996
# 530        Full Moon Sushi and Kitchen Bar       32.715117      -117.160260
# 531                          Cafe Istanbul       32.714916      -117.159284
# 533                         Ramen Yamadaya       32.715721      -117.159623
# 534                       Osteria Panevino       32.712917      -117.160170
# 537                Samba Brazilian Cuisine       32.716878      -117.156964
# 538            Double Standard Kitchenette       32.712422      -117.159217
# 540                           Fogo de Chão       32.712315      -117.159506
# 541                     Pushkin Restaurant       32.713339      -117.159381
# 548                             Searsucker       32.711690      -117.159920
# 558                         Sultan Baklava       32.713317      -117.161004
# 561  Spike Africa's Fresh Fish Bar & Grill       32.715534      -117.160880
# 564                              Bang Bang       32.711713      -117.159438
# 565                             Lotus Thai       32.711599      -117.156309
# 566                        The Smoking Gun       32.711446      -117.159437
# 570                            Urban India       32.716277      -117.161030
#
#      Clus_Db
# 477        0
# 480        0
# 486        1
# 490        1
# 491        1
# 492        1
# 494        1
# 498        1
# 500        1
# 502        1
# 507        1
# 510        1
# 512        1
# 513        1
# 515        1
# 516        1
# 523        1
# 524        2
# 529        1
# 530        1
# 531        1
# 533        1
# 534        1
# 537        1
# 538        1
# 540        1
# 541        1
# 548        1
# 558        1
# 561        1
# 564        1
# 565        3
# 566        1
# 570        1

# %%
# visualize the resulting clusters
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=16)

# set color scheme for the clusters
x = np.arange(5)
ys = [i + x + (i*x)**2 for i in range(5)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df10['Venue Latitude'], df10['Venue Longitude'], df10['Venue'], df10['Clus_Db']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# find the centroid for each cluster
from sklearn.neighbors.nearest_centroid import NearestCentroid
import numpy as np
X = np.array(df10[['Venue Latitude','Venue Longitude']])
y = np.array(df10['Clus_Db'])
clf = NearestCentroid()
clf.fit(X, y)

print(clf.centroids_)
# Out:
# [[  32.71456327 -117.15607955]
#  [  32.71447377 -117.15973498]
#  [  32.71675075 -117.1539721 ]
#  [  32.71159854 -117.15630906]]

# %%
# cluster 1 has the most restaurant nearby, its centroid would be the best place for the grocery store.
print('The best location for the new grocery store is', clf.centroids_[0])
# Out:
# The best location for the new grocery store is [  32.71456327 -117.15607955]
